# %%
import pandas as pd
import matplotlib_inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('NPHA-doctor-visits.csv')
df.head()
# Out:
#    Number of Doctors Visited  Age  Phyiscal Health  Mental Health  \
# 0                          3    2                4              3
# 1                          2    2                4              2
# 2                          3    2                3              2
# 3                          1    2                3              2
# 4                          3    2                3              3
#
#    Dental Health  Employment  Stress Keeps Patient from Sleeping  \
# 0              3           3                                   0
# 1              3           3                                   1
# 2              3           3                                   0
# 3              3           3                                   0
# 4              3           3                                   1
#
#    Medication Keeps Patient from Sleeping  Pain Keeps Patient from Sleeping  \
# 0                                       0                                 0
# ...

# %%
df.shape
# Out:
# (714, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 15 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Number of Doctors Visited                   714 non-null    int64
#  1   Age                                         714 non-null    int64
#  2   Phyiscal Health                             714 non-null    int64
#  3   Mental Health                               714 non-null    int64
#  4   Dental Health                               714 non-null    int64
#  5   Employment                                  714 non-null    int64
#  6   Stress Keeps Patient from Sleeping          714 non-null    int64
#  7   Medication Keeps Patient from Sleeping      714 non-null    int64
#  8   Pain Keeps Patient from Sleeping            714 non-null    int64
#  9   Bathroom Needs Keeps Patient from Sleeping  714 non-null    int64
# ...

# %%
df.describe().T
# Out:
#                                             count      mean       std  min  \
# Number of Doctors Visited                   714.0  2.112045  0.683441  1.0
# Age                                         714.0  2.000000  0.000000  2.0
# Phyiscal Health                             714.0  2.794118  0.900939 -1.0
# Mental Health                               714.0  1.988796  0.939928 -1.0
# Dental Health                               714.0  3.009804  1.361117 -1.0
# Employment                                  714.0  2.806723  0.586582  1.0
# Stress Keeps Patient from Sleeping          714.0  0.247899  0.432096  0.0
# Medication Keeps Patient from Sleeping      714.0  0.056022  0.230126  0.0
# Pain Keeps Patient from Sleeping            714.0  0.218487  0.413510  0.0
# Bathroom Needs Keeps Patient from Sleeping  714.0  0.504202  0.500333  0.0
# Uknown Keeps Patient from Sleeping          714.0  0.417367  0.493470  0.0
# ...

# %%
df.isnull().sum()
# Out:
# Number of Doctors Visited                     0
# Age                                           0
# Phyiscal Health                               0
# Mental Health                                 0
# Dental Health                                 0
# Employment                                    0
# Stress Keeps Patient from Sleeping            0
# Medication Keeps Patient from Sleeping        0
# Pain Keeps Patient from Sleeping              0
# Bathroom Needs Keeps Patient from Sleeping    0
# Uknown Keeps Patient from Sleeping            0
# Trouble Sleeping                              0
# Prescription Sleep Medication                 0
# Race                                          0
# Gender                                        0
# dtype: int64

# %% [markdown]
# - The dataset contains 714 rows and 15 columns.
# - There are no missing values in the dataset.
# - The features in the dataset are all numerical. But according to the data description, the features are categorical.

# %%
df.columns
# Out:
# Index(['Number of Doctors Visited', 'Age', 'Phyiscal Health', 'Mental Health',
#        'Dental Health', 'Employment', 'Stress Keeps Patient from Sleeping',
#        'Medication Keeps Patient from Sleeping',
#        'Pain Keeps Patient from Sleeping',
#        'Bathroom Needs Keeps Patient from Sleeping',
#        'Uknown Keeps Patient from Sleeping', 'Trouble Sleeping',
#        'Prescription Sleep Medication', 'Race', 'Gender'],
#       dtype='object')

# %%
# rename columns
df.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)
df.rename(columns={'Phyiscal_Health': 'Physical_Health'}, inplace=True)
df.columns
# Out:
# Index(['Number_of_Doctors_Visited', 'Age', 'Physical_Health', 'Mental_Health',
#        'Dental_Health', 'Employment', 'Stress_Keeps_Patient_from_Sleeping',
#        'Medication_Keeps_Patient_from_Sleeping',
#        'Pain_Keeps_Patient_from_Sleeping',
#        'Bathroom_Needs_Keeps_Patient_from_Sleeping',
#        'Uknown_Keeps_Patient_from_Sleeping', 'Trouble_Sleeping',
#        'Prescription_Sleep_Medication', 'Race', 'Gender'],
#       dtype='object')

# %% [markdown]
# Here are the features in the dataset:
# - **`Number_of_Doctors_Visited`**: The total count of different doctors the patient has seen = { 1: 0-1 doctors 2: 2-3 doctors 3: 4 or more doctors }
# - **`Age`**: The patient's age group = { 1: 50-64 2: 65-80 }
# - **`Physical_Health`**: A self-assessment of the patient's physical well-being = { -1: Refused 1: Excellent 2: Very Good 3: Good 4: Fair 5: Poor }
# - **`Mental_Health`**: A self-evaluation of the patient's mental or psychological health = { -1: Refused 1: Excellent 2: Very Good 3: Good 4: Fair 5: Poor }
# - **`Dental_Health`**: A self-assessment of the patient's oral or dental health= { -1: Refused 1: Excellent 2: Very Good 3: Good 4: Fair 5: Poor }
# - **`Employment`**: The patient's employment status or work-related information = { -1: Refused 1: Working full-time 2: Working part-time 3: Retired 4: Not working at this time }
# - **`Stress_Keeps_Patient_from_Sleeping`**: Whether stress affects the patient's ability to sleep = { 0: No 1: Yes }
# - **`Medication_Keeps_Patient_from_Sleeping`**: Whether medication impacts the patient's sleep = { 0: No 1: Yes }
# - **`Pain_Keeps_Patient_from_Sleeping`**: Whether physical pain disturbs the patient's sleep = { 0: No 1: Yes }
# - **`Bathroom_Needs_Keeps_Patient_from_Sleeping`**: Whether the need to use the bathroom affects the patient's sleep = { 0: No 1: Yes }
# - **`Uknown_Keeps_Patient_from_Sleeping`**: Unidentified factors affecting the patient's sleep = { 0: No 1: Yes }
# - **`Trouble_Sleeping`**: General issues or difficulties the patient faces with sleeping = { 0: No 1: Yes }
# - **`Prescription_Sleep_Medication`**: Information about any sleep medication prescribed to the patient = { -1: Refused 1: Use regularly 2: Use occasionally 3: Do not use }
# - **`Race`**: The patient's racial or ethnic background = { -2: Not asked -1: REFUSED 1: White, Non-Hispanic 2: Black, Non-Hispanic 3: Other, Non-Hispanic 4: Hispanic 5: 2+ Races, Non-Hispanic }
# - **`Gender`**: The gender identity of the patient = { -2: Not asked -1: REFUSED 1: Male 2: Female }

# %% [markdown]
# Next, we'll convert all the features to categorical data types.

# %%
columns = df.columns
for column in columns:
    df[column] = df[column].astype('category')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 15 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Number_of_Doctors_Visited                   714 non-null    category
#  1   Age                                         714 non-null    category
#  2   Physical_Health                             714 non-null    category
#  3   Mental_Health                               714 non-null    category
#  4   Dental_Health                               714 non-null    category
#  5   Employment                                  714 non-null    category
#  6   Stress_Keeps_Patient_from_Sleeping          714 non-null    category
#  7   Medication_Keeps_Patient_from_Sleeping      714 non-null    category
#  8   Pain_Keeps_Patient_from_Sleeping            714 non-null    category
# ...

# %%
df.describe().T
# Out:
#                                             count  unique  top  freq
# Number_of_Doctors_Visited                     714       3    2   372
# Age                                           714       1    2   714
# Physical_Health                               714       6    3   291
# Mental_Health                                 714       6    2   282
# Dental_Health                                 714       7    2   215
# Employment                                    714       4    3   592
# Stress_Keeps_Patient_from_Sleeping            714       2    0   537
# Medication_Keeps_Patient_from_Sleeping        714       2    0   674
# Pain_Keeps_Patient_from_Sleeping              714       2    0   558
# Bathroom_Needs_Keeps_Patient_from_Sleeping    714       2    1   360
# Uknown_Keeps_Patient_from_Sleeping            714       2    0   416
# Trouble_Sleeping                              714       4    3   359
# Prescription_Sleep_Medication                 714       4    3   639
# ...

# %% [markdown]
# # NB
# 1. From the description of the dataset, there're supposed to be two categories of ths `Age` groups, but only one is represented in the dataset.
# 2. `Dental_Health` shows 7 unique values instead of 6. We'll investigate this further.
# 3. One category in `Employment` is not represented in the dataset.
# 4. `Trouble_Sleeping` has 4 unique values instead of 2.
# 5. Two categories in `Race` are not represented in the dataset.
# 6. Two categories in `Gender` are not represented in the dataset.

# %%
df['Dental_Health'].value_counts()
# Out:
# Dental_Health
# 2     215
# 3     208
# 4     127
# 1      66
# 6      55
# 5      39
# -1      4
# Name: count, dtype: int64

# %% [markdown]
# There's a new category (6) in the `Dental_Health` column. We can either drop this category or merge it with the 'Refused' category. We'll merge it with the 'Refused' category.

# %%
df['Dental_Health'] = df['Dental_Health'].replace(6, -1)

# %%
df['Trouble_Sleeping'].value_counts()
# Out:
# Trouble_Sleeping
# 3     359
# 2     291
# 1      62
# -1      2
# Name: count, dtype: int64

# %% [markdown]
# The solution to the `Trouble_Sleeping` column is to merge the -1 and 1 into 2, and change the 2 to 0 and 3 to 1.

# %%
df['Trouble_Sleeping'] = df['Trouble_Sleeping'].replace(-1, 2)
df['Trouble_Sleeping'] = df['Trouble_Sleeping'].replace(1, 2)
df['Trouble_Sleeping'] = df['Trouble_Sleeping'].replace(2, 0)
df['Trouble_Sleeping'] = df['Trouble_Sleeping'].replace(3, 1)

# %%
df.describe().T
# Out:
#                                             count  unique  top  freq
# Number_of_Doctors_Visited                     714       3    2   372
# Age                                           714       1    2   714
# Physical_Health                               714       6    3   291
# Mental_Health                                 714       6    2   282
# Dental_Health                                 714       6    2   215
# Employment                                    714       4    3   592
# Stress_Keeps_Patient_from_Sleeping            714       2    0   537
# Medication_Keeps_Patient_from_Sleeping        714       2    0   674
# Pain_Keeps_Patient_from_Sleeping              714       2    0   558
# Bathroom_Needs_Keeps_Patient_from_Sleeping    714       2    1   360
# Uknown_Keeps_Patient_from_Sleeping            714       2    0   416
# Trouble_Sleeping                              714       2    1   359
# Prescription_Sleep_Medication                 714       4    3   639
# ...

# %%
# visualizing the distribution of the features
fig, axes = plt.subplots(3, 5, figsize=(20, 15))
axes = axes.ravel()

for i, column in enumerate(df.columns):
    df[column].value_counts().plot(kind='bar', ax=axes[i])
    axes[i].set_title(column)

plt.tight_layout()
plt.show()

# %%
# visualizing the distribution of the features

fig, axes = plt.subplots(3, 5, figsize=(20, 15))
axes = axes.ravel()

for i, column in enumerate(df.columns):
    sns.histplot(df[column], ax=axes[i])
    axes[i].set_title(column)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Since the there's only one age group in the dataset, we'll drop the `Age` column.

# %% [markdown]
# Number_of_Doctors_Visited - 3
# Age - 2
# Physical_Health - 6
# Mental_Health - 6
# Dental_Health - 6
# Employment - 5
# Stress_Keeps_Patient_from_Sleeping - 2
# Medication_Keeps_Patient_from_Sleeping - 2
# Pain_Keeps_Patient_from_Sleeping - 2
# Bathroom_Needs_Keeps_Patient_from_Sleeping - 2
# Uknown_Keeps_Patient_from_Sleeping - 2
# Trouble_Sleeping - 2
# Prescription_Sleep_Medication - 4
# Race - 7
# Gender - 4
